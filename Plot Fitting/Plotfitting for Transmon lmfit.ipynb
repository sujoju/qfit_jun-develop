# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
from lmfit import Minimizer, Parameters

import numpy as np

import scqubits as scq

# %%
def func(pars, x, data=None):
    a, b = pars['a'], pars['b']
    transmon = scq.Transmon(EJ = 30.02,
                            EC = a,
                            ng = b,
                            ncut = 31)
    specdata = transmon.get_spectrum_vs_paramvals('EJ',
                                                  x,
                                                  evals_count = 3,
                                                  subtract_ground = True)
    model = specdata.energy_table[:,1]
    if data is None:
        return model
    return model - data


def f(var, x):
    transmon = scq.Transmon(EJ = 30.02,
                            EC = var[0],
                            ng = var[1],
                            ncut = 31)
    specdata = transmon.get_spectrum_vs_paramvals('EJ',
                                                  x,
                                                  evals_count = 3,
                                                  subtract_ground = True)
    return specdata.energy_table[:,1]


params = Parameters()
params.add('a', value=5)
params.add('b', value=0)

a, b = 1.2, 0.3
x = np.linspace(0, 50, 50)
y = f([a, b], x)
data = y + 0.25*np.random.normal(size=x.size)

# fit without analytic derivative
min1 = Minimizer(func, params, fcn_args=(x,), fcn_kws={'data': data})
out1 = min1.leastsq()
fit1 = func(out1.params, x)
# Out:
# Spectral data:   0%|          | 0/50 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-e0dc30fc3d53> in <module>
#      34 x = np.linspace(0, 50, 50)
#      35 y = f([a, b], x)
# ---> 36 data = y + 0.25*np.random.randint(0,1, size=(50,3))
#      37
#      38 # fit without analytic derivative
#
# ValueError: operands could not be broadcast together with shapes (50,) (50,3)

# %%
print('''
"true" parameters are: a = %.3f, b = %.3f

==================================
Statistic/Parameter|   Without   |
----------------------------------
N Function Calls   |   %3i       |
Chi-square         |   %.4f    |
   a               |   %.4f    |
   b               |   %.4f    |
--------------------------------
''' % (a, b,
       out1.nfev,
       out1.chisqr,
       out1.params['a'],
       out1.params['b'], ))
# Out:
# "true" parameters are: a = 1.200, b = 0.300
#
# ==================================
# Statistic/Parameter|   Without   |
# ----------------------------------
# N Function Calls   |    19       |
# Chi-square         |   3.1039    |
#    a               |   1.2074    |
#    b               |   0.7001    |
# --------------------------------

# %%
plt.plot(x, data, 'ro')
plt.plot(x, fit1, 'b')
plt.show()

# %%
scq.GUI()
# Out:
# VBox(children=(HBox(children=(ToggleButtons(description='Qubits:', layout=Layout(width='800px'), options=('Tra…
# Output(layout=Layout(width='975px'))
